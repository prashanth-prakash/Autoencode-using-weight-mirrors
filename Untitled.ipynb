# %%
import matplotlib.pyplot as plt
import os
import json
import numpy as np
import matplotlib
matplotlib.use('Agg')


def leafcounter(node):
    '''
    Description: helper function to count the number of lists in a dicitonary.
                 Knowing the number of data to plot will determine the number
                 of distinct color to create
    Params: node = the dictionary containing saved data
    Outputs: the number of lists to plot
    '''
    if isinstance(node, dict):
        return sum([leafcounter(node[n]) for n in node])
    else:
        return 1


def get_spaced_colors(n):
    '''
    Description: generate n equally spaced colors
    Params: n = the number of color to generate
    Outputs: a generator containing n generated colors
    '''
    cm = plt.get_cmap('gist_rainbow')
    for i in range(n):
        yield cm(1. * i / n)


def plot_list_variables(data, dataset_name, x_axis_name, y_axis_name, save_dir):
    '''
    Description: plot non nested dictionary of data
    Params: data = the dictionary to plot
            x_axis_name = the name of the x-axis
            y_axis_name = the name of the y-axis
            save_dir = the directory where to save the figures
    Outputs: Pre-processed image features and labels
    '''
    colors = get_spaced_colors(len(data.keys()))
    for algo_name, algo_data in data.items():
        plt.plot(list(np.arange(len(algo_data))), algo_data, color=next(colors))
    plt.legend(tuple(list(data.keys())))

    plt.xlabel(x_axis_name)
    plt.ylabel(y_axis_name)
    plt.ylim((0, 100))
    plt.title('{} on {}'.format(y_axis_name.replace("_", " "), dataset_name))
    plt.savefig('{}/{}.png'.format(save_dir, y_axis_name.replace(" ", "_")))
    plt.clf()


def plot_dict_variables(data, dataset_name, x_axis_name, y_axis_name, save_dir):
    '''
    Description: plot nested dictionary of data
    Params: data = the dictionary to plot
            x_axis_name = the name of the x-axis
            y_axis_name = the name of the y-axis
            save_dir = the directory where to save the figures
    Outputs: Pre-processed image features and labels
    '''
    colors = get_spaced_colors(leafcounter(data))
    labels = []
    for algo_name, algo_data in data.items():
        for i, (layer, layer_data) in enumerate(algo_data.items()):
            plt.plot(list(np.arange(len(layer_data))), layer_data, color=next(colors))
            labels.append("{} {}".format(algo_name, layer))
    plt.legend(labels)

    plt.xlabel(x_axis_name)
    plt.ylabel(y_axis_name)
    plt.ylim((0, 120))
    plt.title('{} on {}'.format(y_axis_name.replace("_", " "), dataset_name))
    plt.savefig('{}/{}.png'.format(save_dir, y_axis_name.replace(" ", "_")))
    plt.clf()


def read_data():
    '''
    Description: read the json files of all experiments
    Outputs: a dictionary containing all the json files
    '''
    json_files = {}
    for subdir, dirs, files in os.walk('./experiments'):
#         print(subdir, dirs, files)
        for file in files:
            if file.endswith('.json'):
                with open(os.path.join(subdir, file), 'r') as f:
                    print(os.path.join(subdir, file))
                    algo = subdir.split("/")[-1].split('-')[0]
                    dataset = subdir.split("/")[-2]
                    if not dataset in json_files.keys():
                        json_files[dataset] = {}
                    json_files[dataset][algo] = json.load(f)
    return json_files


def generate_dataset_figures(json_files, dataset_name, save_dir):
    '''
    Description: generate the figures of all experiments
    Params: data = the data dictionary to all experiments
            save_dir = the directory where to save the figures
    Outputs: Pre-processed image features and labels
    '''
    # Initialize variables to plot
    losses = {algo: [] for algo in json_files.keys()}
    test_accuracies = {algo: [] for algo in json_files.keys()}
    delta_angles = {algo: {} for algo in json_files.keys() if algo != 'bp'}
    weight_angles = {algo: {} for algo in json_files.keys() if algo != 'bp'}

    for algo_name, algo_data in json_files.items():

        for _, epoch_data in algo_data.items():
            losses[algo_name].append(epoch_data['loss'])
            test_accuracies[algo_name].append(epoch_data['test_accuracy'])
            if algo_name != 'bp':
                for layer, angle in epoch_data['delta_angles'].items():
                    if layer in delta_angles[algo_name].keys():
                        delta_angles[algo_name][layer].append(angle)
                    else:
                        delta_angles[algo_name][layer] = [angle]

                for layer, angle in epoch_data['weight_angles'].items():
                    if layer in weight_angles[algo_name].keys():
                        weight_angles[algo_name][layer].append(angle)
                    else:
                        weight_angles[algo_name][layer] = [angle]

    # plot the `loss`, `test_accuracy`, `delta_angles` and `weight_angles`
    plot_list_variables(losses, dataset_name, 'epochs', 'loss', save_dir)
    plot_list_variables(test_accuracies, dataset_name, 'epochs', 'test_accuracies', save_dir)
    plot_dict_variables(delta_angles, dataset_name, 'epochs', 'delta_angles', save_dir)
    plot_dict_variables(weight_angles, dataset_name, 'epochs', 'weight_angles', save_dir)
# Out:
# /opt/anaconda/miniconda2/lib/python2.7/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
json_files = read_data()

with open('./experiments/mnist/wm-V12/results_test.json') as f:
  a=  json.load(f)
    # Generate figures
# for dataset_name, data in json_files.items():
#     save_dir = os.path.join('figures', dataset_name)
#     if not os.path.exists(save_dir):
#         os.makedirs(save_dir)
#     generate_dataset_figures(data, dataset_name, save_dir)
# Out:
# ./experiments/cifar10/fa-V0/results.json
# ./experiments/cifar10/kp-V0/results.json
# ./experiments/cifar10/wm-V0/results.json
# ./experiments/cifar10/bp-V0/results.json
# ./experiments/mnist/fa-V0/results.json
# ./experiments/mnist/wm-V10/results_test.json
# ./experiments/mnist/wm-V12/results_test.json
# ./experiments/mnist/wm-V8/results_test.json
# ./experiments/mnist/kp-V0/results.json
# ./experiments/mnist/wm-V9/results_test.json
# ./experiments/mnist/wm-V3/results.json
# ./experiments/mnist/wm-V0/results.json
# ./experiments/mnist/bp-V0/results.json

# %%
tst_acc=[]
loss_plt=[]

# %%
for key in a:
    loss_plt.append(a[key]['loss'])
    tst_acc.append(a[key]['test_accuracy'])

# %%
plt.plot(loss_plt)
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.title("learning rate=0.1; mirror_learning_rate=0.01")
plt.show()

# %%
plt.plot(tst_acc)
plt.xlabel("iterations")
plt.ylabel("Testing accuracy")
plt.title("learning rate=0.1; mirror_learning_rate=0.01")
plt.show()

# %%
# json_files = read_data()
# json_files.keys()
# Out:
# ./experiments/cifar10/fa-V0/results.json
# ./experiments/cifar10/kp-V0/results.json
# ./experiments/cifar10/wm-V0/results.json
# ./experiments/cifar10/bp-V0/results.json
# ./experiments/mnist/fa-V0/results.json
# ./experiments/mnist/wm-V10/results_test.json
# ./experiments/mnist/wm-V12/results_test.json
# ./experiments/mnist/wm-V8/results_test.json
# ./experiments/mnist/kp-V0/results.json
# ./experiments/mnist/wm-V9/results_test.json
# ./experiments/mnist/wm-V3/results.json
# ./experiments/mnist/wm-V0/results.json
# ./experiments/mnist/bp-V0/results.json
# ['mnist', 'cifar10']

# %%
# json_files['mnist']['wm']
# Out:
# {u'epoch_0': {u'delta_angles': {u'layer_1': 63.43539625983123},
#   u'loss': 2.585274739111235,
#   u'test_accuracy': 78.48,
#   u'weight_angles': {u'layer_0': 83.16215197903317,
#    u'layer_1': 61.334420958374515}},
#  u'epoch_1': {u'delta_angles': {u'layer_1': 46.75944916157913},
#   u'loss': 1.5195894796991962,
#   u'test_accuracy': 84.23,
#   u'weight_angles': {u'layer_0': 81.30663499797073,
#    u'layer_1': 53.151368889401546}},
#  u'epoch_10': {u'delta_angles': {u'layer_1': 15.379563518415292},
#   u'loss': 0.7054575638583166,
#   u'test_accuracy': 90.72,
#   u'weight_angles': {u'layer_0': 71.17437461856183,
#    u'layer_1': 26.341969492297828}},
#  u'epoch_100': {u'delta_angles': {u'layer_1': 9.075179569449816},
#   u'loss': 0.08829700590460732,
#   u'test_accuracy': 97.98,
#   u'weight_angles': {u'layer_0': 33.672611633468975,
#    u'layer_1': 9.246665820959814}},
#  u'epoch_101': {u'delta_angles': {u'layer_1': 9.029232831635225},
#   u'loss': 0.08680393211432065,
#   u'test_accuracy': 97.98,
#   u'weight_angles': {u'layer_0': 33.46371268348801,
#    u'layer_1': 9.195384103142642}},
#  u'epoch_102': {u'delta_angles': {u'layer_1': 8.990041866042018},
#   u'loss': 0.08533965034241449,
#   u'test_accuracy': 97.99,
#   u'weight_angles': {u'layer_0': 33.18472515391135,
#    u'layer_1': 9.166056136641192}},
#  u'epoch_103': {u'delta_angles': {u'layer_1': 8.928741944927003},
#   u'loss': 0.083903112619596,
#   u'test_accuracy': 98.0,
#   u'weight_angles': {u'layer_0': 32.950321071402364,
#    u'layer_1': 9.103953037031353}},
#  u'epoch_104': {u'delta_angles': {u'layer_1': 8.92782957849567},
#   u'loss': 0.08249369140832144,
#   u'test_accuracy': 98.03,
#   u'weight_angles': {u'layer_0': 32.78445784642035,
#    u'layer_1': 9.062272645190598}},
#  u'epoch_105': {u'delta_angles': {u'layer_1': 8.851368298080848},
#   u'loss': 0.08111082883239691,
#   u'test_accuracy': 98.02,
#   u'weight_angles': {u'layer_0': 32.54698732651246,
#    u'layer_1': 9.004745706017646}},
#  u'epoch_106': {u'delta_angles': {u'layer_1': 8.826057276767115},
#   u'loss': 0.07975414703870404,
#   u'test_accuracy': 98.03,
#   u'weight_angles': {u'layer_0': 32.357258392658196,
#    u'layer_1': 8.954162698878822}},
#  u'epoch_107': {u'delta_angles': {u'layer_1': 8.758652718469342},
#   u'loss': 0.07842280536631037,
#   u'test_accuracy': 98.03,
#   u'weight_angles': {u'layer_0': 32.239554906367815,
#    u'layer_1': 8.903096389081274}},
#  u'epoch_108': {u'delta_angles': {u'layer_1': 8.697560704448298},
#   u'loss': 0.07711601015583153,
#   u'test_accuracy': 98.04,
#   u'weight_angles': {u'layer_0': 32.0446970347009,
#    u'layer_1': 8.86580660652359}},
#  u'epoch_109': {u'delta_angles': {u'layer_1': 8.58230984426522},
#   u'loss': 0.07583374516987165,
#   u'test_accuracy': 98.08,
#   u'weight_angles': {u'layer_0': 31.89374938526401,
#    u'layer_1': 8.815233245190164}},
#  u'epoch_11': {u'delta_angles': {u'layer_1': 13.619496945228905},
#   u'loss': 0.6873518518020347,
#   u'test_accuracy': 90.95,
#   u'weight_angles': {u'layer_0': 70.31874433536711,
#    u'layer_1': 25.15124806525253}},
#  u'epoch_110': {u'delta_angles': {u'layer_1': 8.472729621164845},
#   u'loss': 0.07457511533600568,
#   u'test_accuracy': 98.09,
#   u'weight_angles': {u'layer_0': 31.62455295722195,
#    u'layer_1': 8.765361384764837}},
#  u'epoch_111': {u'delta_angles': {u'layer_1': 8.397605308914224},
#   u'loss': 0.0733396801509791,
#   u'test_accuracy': 98.11,
#   u'weight_angles': {u'layer_0': 31.4248535849451,
#    u'layer_1': 8.701768365282554}},
#  u'epoch_112': {u'delta_angles': {u'layer_1': 8.318971789215098},
#   u'loss': 0.07212703277808405,
#   u'test_accuracy': 98.11,
#   u'weight_angles': {u'layer_0': 31.21163572528033,
#    u'layer_1': 8.663728597834096}},
#  u'epoch_113': {u'delta_angles': {u'layer_1': 8.172283865127298},
#   u'loss': 0.07093728063848748,
#   u'test_accuracy': 98.14,
#   u'weight_angles': {u'layer_0': 31.082125710324746,
#    u'layer_1': 8.616784010623054}},
#  u'epoch_114': {u'delta_angles': {u'layer_1': 8.106238033709483},
#   u'loss': 0.06976881806181674,
#   u'test_accuracy': 98.15,
#   u'weight_angles': {u'layer_0': 30.919085274703704,
#    u'layer_1': 8.597391815515692}},
#  u'epoch_115': {u'delta_angles': {u'layer_1': 8.061126628878608},
#   u'loss': 0.06862226891048762,
#   u'test_accuracy': 98.15,
#   u'weight_angles': {u'layer_0': 30.743193962155953,
#    u'layer_1': 8.559856547722973}},
#  u'epoch_116': {u'delta_angles': {u'layer_1': 8.006060830700997},
#   u'loss': 0.0674968005619608,
#   u'test_accuracy': 98.16,
#   u'weight_angles': {u'layer_0': 30.49155385984978,
#    u'layer_1': 8.529530360342608}},
#  u'epoch_117': {u'delta_angles': {u'layer_1': 7.984971211882767},
#   u'loss': 0.06639179457599005,
#   u'test_accuracy': 98.16,
#   u'weight_angles': {u'layer_0': 30.30027574247539,
#    u'layer_1': 8.48648423389517}},
#  u'epoch_118': {u'delta_angles': {u'layer_1': 7.859720606743675},
#   u'loss': 0.06530685919919646,
#   u'test_accuracy': 98.17,
#   u'weight_angles': {u'layer_0': 30.316383952479388,
#    u'layer_1': 8.43417213415633}},
#  u'epoch_119': {u'delta_angles': {u'layer_1': 7.801294061084199},
#   u'loss': 0.06424183167275922,
#   u'test_accuracy': 98.18,
#   u'weight_angles': {u'layer_0': 30.17284593683248,
#    u'layer_1': 8.391042032787194}},
#  u'epoch_12': {u'delta_angles': {u'layer_1': 11.668511396103984},
#   u'loss': 0.6704029795282787,
#   u'test_accuracy': 91.18,
#   u'weight_angles': {u'layer_0': 69.22506166051124,
#    u'layer_1': 23.8683242428782}},
#  u'epoch_120': {u'delta_angles': {u'layer_1': 7.734484533399662},
#   u'loss': 0.06319653685263862,
#   u'test_accuracy': 98.18,
#   u'weight_angles': {u'layer_0': 29.97817486582193,
#    u'layer_1': 8.337061367375606}},
#  u'epoch_121': {u'delta_angles': {u'layer_1': 7.732339753505323},
#   u'loss': 0.06216989589723711,
#   u'test_accuracy': 98.18,
#   u'weight_angles': {u'layer_0': 29.871581331092482,
#    u'layer_1': 8.310499933174015}},
#  u'epoch_122': {u'delta_angles': {u'layer_1': 7.69862071834755},
#   u'loss': 0.06116241707369839,
#   u'test_accuracy': 98.18,
#   u'weight_angles': {u'layer_0': 29.78923238593203,
#    u'layer_1': 8.278523375210895}},
#  u'epoch_123': {u'delta_angles': {u'layer_1': 7.659148647572178},
#   u'loss': 0.0601732419793267,
#   u'test_accuracy': 98.18,
#   u'weight_angles': {u'layer_0': 29.583613958370464,
#    u'layer_1': 8.225846629377667}},
#  u'epoch_124': {u'delta_angles': {u'layer_1': 7.600692228617419},
#   u'loss': 0.0592025201227087,
#   u'test_accuracy': 98.18,
#   u'weight_angles': {u'layer_0': 29.518408755918774,
#    u'layer_1': 8.17148756842492}},
#  u'epoch_125': {u'delta_angles': {u'layer_1': 7.629121081311759},
#   u'loss': 0.058249623658309116,
#   u'test_accuracy': 98.19,
#   u'weight_angles': {u'layer_0': 29.37180953562042,
#    u'layer_1': 8.142394526691938}},
#  u'epoch_126': {u'delta_angles': {u'layer_1': 7.632213882265825},
#   u'loss': 0.057313893824702415,
#   u'test_accuracy': 98.19,
#   u'weight_angles': {u'layer_0': 29.208479535073707,
#    u'layer_1': 8.109972687896526}},
#  u'epoch_127': {u'delta_angles': {u'layer_1': 7.582963212078403},
#   u'loss': 0.05639556872407719,
#   u'test_accuracy': 98.22,
#   u'weight_angles': {u'layer_0': 29.123517006017288,
#    u'layer_1': 8.090441805042259}},
#  u'epoch_128': {u'delta_angles': {u'layer_1': 7.532647003955916},
#   u'loss': 0.05549398415000151,
#   u'test_accuracy': 98.23,
#   u'weight_angles': {u'layer_0': 29.036204289423328,
#    u'layer_1': 8.05446797292197}},
#  u'epoch_129': {u'delta_angles': {u'layer_1': 7.486423588685093},
#   u'loss': 0.054608608814651384,
#   u'test_accuracy': 98.23,
#   u'weight_angles': {u'layer_0': 28.779488900200935,
#    u'layer_1': 8.019673646952722}},
#  u'epoch_13': {u'delta_angles': {u'layer_1': 9.955441606535002},
#   u'loss': 0.6540935238079556,
#   u'test_accuracy': 91.39,
#   u'weight_angles': {u'layer_0': 68.25143828945812,
#    u'layer_1': 23.095507376579445}},
#  u'epoch_130': {u'delta_angles': {u'layer_1': 7.41125198300875},
#   u'loss': 0.0537397719145906,
#   u'test_accuracy': 98.23,
#   u'weight_angles': {u'layer_0': 28.646201635032487,
#    u'layer_1': 7.97014341288673}},
#  u'epoch_131': {u'delta_angles': {u'layer_1': 7.372712214153384},
#   u'loss': 0.05288685505592865,
#   u'test_accuracy': 98.23,
#   u'weight_angles': {u'layer_0': 28.52672701151888,
#    u'layer_1': 7.942413559665959}},
#  u'epoch_132': {u'delta_angles': {u'layer_1': 7.306471751318592},
#   u'loss': 0.0520498572372494,
#   u'test_accuracy': 98.24,
#   u'weight_angles': {u'layer_0': 28.38253038234106,
#    u'layer_1': 7.898327474019987}},
#  u'epoch_133': {u'delta_angles': {u'layer_1': 7.2618280252205265},
#   u'loss': 0.05122805345603154,
#   u'test_accuracy': 98.25,
#   u'weight_angles': {u'layer_0': 28.270757452793667,
#    u'layer_1': 7.873274131183475}},
#  u'epoch_134': {u'delta_angles': {u'layer_1': 7.218996648955327},
#   u'loss': 0.05042148723893193,
#   u'test_accuracy': 98.25,
#   u'weight_angles': {u'layer_0': 28.054906728818562,
#    u'layer_1': 7.826593618519689}},
#  u'epoch_135': {u'delta_angles': {u'layer_1': 7.149730640973916},
#   u'loss': 0.04962981024430028,
#   u'test_accuracy': 98.24,
#   u'weight_angles': {u'layer_0': 27.872981468029224,
#    u'layer_1': 7.776447129838595}},
#  u'epoch_136': {u'delta_angles': {u'layer_1': 7.037238295140829},
#   u'loss': 0.04885264543350498,
#   u'test_accuracy': 98.24,
#   u'weight_angles': {u'layer_0': 27.829037899778896,
#    u'layer_1': 7.749845235107934}},
#  u'epoch_137': {u'delta_angles': {u'layer_1': 6.982290690969091},
#   u'loss': 0.048089805397529814,
#   u'test_accuracy': 98.25,
#   u'weight_angles': {u'layer_0': 27.67940058897342,
#    u'layer_1': 7.710295964875187}},
#  u'epoch_138': {u'delta_angles': {u'layer_1': 6.952529572737105},
#   u'loss': 0.04734131808861076,
#   u'test_accuracy': 98.25,
#   u'weight_angles': {u'layer_0': 27.522878356638284,
#    u'layer_1': 7.686458017694177}},
#  u'epoch_139': {u'delta_angles': {u'layer_1': 6.9251754938499746},
#   u'loss': 0.04660651408476927,
#   u'test_accuracy': 98.25,
#   u'weight_angles': {u'layer_0': 27.310097086664914,
#    u'layer_1': 7.6463664428388975}},
#  u'epoch_14': {u'delta_angles': {u'layer_1': 8.371599539909521},
#   u'loss': 0.6381122512378666,
#   u'test_accuracy': 91.6,
#   u'weight_angles': {u'layer_0': 67.6237712016607,
#    u'layer_1': 22.331287234322133}},
#  u'epoch_140': {u'delta_angles': {u'layer_1': 6.836015672913714},
#   u'loss': 0.04588570954749461,
#   u'test_accuracy': 98.27,
#   u'weight_angles': {u'layer_0': 27.141916451487734,
#    u'layer_1': 7.601215981626532}},
#  u'epoch_141': {u'delta_angles': {u'layer_1': 6.7750349687936104},
#   u'loss': 0.04517815411449169,
#   u'test_accuracy': 98.25,
#   u'weight_angles': {u'layer_0': 26.986617719448713,
#    u'layer_1': 7.567523105016}},
#  u'epoch_142': {u'delta_angles': {u'layer_1': 6.721976463788603},
#   u'loss': 0.044483657408679045,
#   u'test_accuracy': 98.25,
#   u'weight_angles': {u'layer_0': 26.853854124991503,
#    u'layer_1': 7.52794803864527}},
#  u'epoch_143': {u'delta_angles': {u'layer_1': 6.66542691337399},
#   u'loss': 0.04380209492300003,
#   u'test_accuracy': 98.26,
#   u'weight_angles': {u'layer_0': 26.77978626805779,
#    u'layer_1': 7.485863287537756}},
#  u'epoch_144': {u'delta_angles': {u'layer_1': 6.657394947548357},
#   u'loss': 0.04313342126653414,
#   u'test_accuracy': 98.26,
#   u'weight_angles': {u'layer_0': 26.59208855625247,
#    u'layer_1': 7.446126080987637}},
#  u'epoch_145': {u'delta_angles': {u'layer_1': 6.634683272838432},
#   u'loss': 0.042477266027701736,
#   u'test_accuracy': 98.28,
#   u'weight_angles': {u'layer_0': 26.5341225354641,
#    u'layer_1': 7.413458068386753}},
#  u'epoch_146': {u'delta_angles': {u'layer_1': 6.583014929307156},
#   u'loss': 0.04183327640894,
#   u'test_accuracy': 98.28,
#   u'weight_angles': {u'layer_0': 26.424111993427772,
#    u'layer_1': 7.374771173931106}},
#  u'epoch_147': {u'delta_angles': {u'layer_1': 6.49057982288986},
#   u'loss': 0.041201303566944306,
#   u'test_accuracy': 98.28,
#   u'weight_angles': {u'layer_0': 26.328480990642138,
#    u'layer_1': 7.343231909884646}},
#  u'epoch_148': {u'delta_angles': {u'layer_1': 6.421819048837383},
#   u'loss': 0.04058123322982348,
#   u'test_accuracy': 98.28,
#   u'weight_angles': {u'layer_0': 26.177679939347655,
#    u'layer_1': 7.313546564855117}},
#  u'epoch_149': {u'delta_angles': {u'layer_1': 6.398222269045318},
#   u'loss': 0.03997280032573244,
#   u'test_accuracy': 98.28,
#   u'weight_angles': {u'layer_0': 26.095924683898257,
#    u'layer_1': 7.284426430832334}},
#  u'epoch_15': {u'delta_angles': {u'layer_1': 7.041588334423636},
#   u'loss': 0.6221999223143311,
#   u'test_accuracy': 91.77,
#   u'weight_angles': {u'layer_0': 66.98563716024859,
#    u'layer_1': 21.54919390574061}},
#  u'epoch_150': {u'delta_angles': {u'layer_1': 6.378841590107539},
#   u'loss': 0.03937593292659621,
#   u'test_accuracy': 98.28,
#   u'weight_angles': {u'layer_0': 25.99199324445734,
#    u'layer_1': 7.252464424355264}},
#  u'epoch_151': {u'delta_angles': {u'layer_1': 6.358159428328687},
#   u'loss': 0.03879016234579432,
#   u'test_accuracy': 98.28,
#   u'weight_angles': {u'layer_0': 25.795146035880162,
#    u'layer_1': 7.21459199657232}},
#  u'epoch_152': {u'delta_angles': {u'layer_1': 6.321940998887559},
#   u'loss': 0.038215328003883164,
#   u'test_accuracy': 98.28,
#   u'weight_angles': {u'layer_0': 25.663616202110795,
#    u'layer_1': 7.1940739370547035}},
#  u'epoch_153': {u'delta_angles': {u'layer_1': 6.3057414504916105},
#   u'loss': 0.037651103601618365,
#   u'test_accuracy': 98.29,
#   u'weight_angles': {u'layer_0': 25.506337180455,
#    u'layer_1': 7.174682212116978}},
#  u'epoch_154': {u'delta_angles': {u'layer_1': 6.3328689872304205},
#   u'loss': 0.03709766990484321,
#   u'test_accuracy': 98.31,
#   u'weight_angles': {u'layer_0': 25.40995822736974,
#    u'layer_1': 7.152516970939924}},
#  u'epoch_155': {u'delta_angles': {u'layer_1': 6.256592388429589},
#   u'loss': 0.03655444747149869,
#   u'test_accuracy': 98.31,
#   u'weight_angles': {u'layer_0': 25.226196159931202,
#    u'layer_1': 7.109601062667282}},
#  u'epoch_156': {u'delta_angles': {u'layer_1': 6.248238281002844},
#   u'loss': 0.03602154344358947,
#   u'test_accuracy': 98.31,
#   u'weight_angles': {u'layer_0': 25.14411644667765,
#    u'layer_1': 7.075340103582279}},
#  u'epoch_157': {u'delta_angles': {u'layer_1': 6.166285833787771},
#   u'loss': 0.03549840913117213,
#   u'test_accuracy': 98.31,
#   u'weight_angles': {u'layer_0': 25.075361384294037,
#    u'layer_1': 7.04555808814128}},
#  u'epoch_158': {u'delta_angles': {u'layer_1': 6.129491022963171},
#   u'loss': 0.03498515345036132,
#   u'test_accuracy': 98.31,
#   u'weight_angles': {u'layer_0': 24.944945980769738,
#    u'layer_1': 7.006958328744399}},
#  u'epoch_159': {u'delta_angles': {u'layer_1': 6.082450235131964},
#   u'loss': 0.034481565821080015,
#   u'test_accuracy': 98.31,
#   u'weight_angles': {u'layer_0': 24.861092069120215,
#    u'layer_1': 6.983465609884806}},
#  u'epoch_16': {u'delta_angles': {u'layer_1': 6.272575753761099},
#   u'loss': 0.606161972291705,
#   u'test_accuracy': 91.98,
#   u'weight_angles': {u'layer_0': 66.09905466380633,
#    u'layer_1': 20.6326235749538}},
#  u'epoch_160': {u'delta_angles': {u'layer_1': 6.071361514507191},
#   u'loss': 0.033987503775648464,
#   u'test_accuracy': 98.31,
#   u'weight_angles': {u'layer_0': 24.7156051610355,
#    u'layer_1': 6.949833183045232}},
#  u'epoch_161': {u'delta_angles': {u'layer_1': 5.994329488120482},
#   u'loss': 0.03350262533437964,
#   u'test_accuracy': 98.32,
#   u'weight_angles': {u'layer_0': 24.581713302624753,
#    u'layer_1': 6.9213344556632075}},
#  u'epoch_162': {u'delta_angles': {u'layer_1': 5.9161088487493885},
#   u'loss': 0.03302673009392302,
#   u'test_accuracy': 98.33,
#   u'weight_angles': {u'layer_0': 24.478763278970725,
#    u'layer_1': 6.894310996086202}},
#  u'epoch_163': {u'delta_angles': {u'layer_1': 5.875248261444608},
#   u'loss': 0.03255961146708589,
#   u'test_accuracy': 98.34,
#   u'weight_angles': {u'layer_0': 24.35729915951105,
#    u'layer_1': 6.865557727914113}},
#  u'epoch_164': {u'delta_angles': {u'layer_1': 5.870773886713969},
#   u'loss': 0.03210130602266456,
#   u'test_accuracy': 98.34,
#   u'weight_angles': {u'layer_0': 24.267356301011684,
#    u'layer_1': 6.848188626499334}},
#  u'epoch_165': {u'delta_angles': {u'layer_1': 5.8236408869669125},
#   u'loss': 0.031651570285752814,
#   u'test_accuracy': 98.34,
#   u'weight_angles': {u'layer_0': 24.15627837179153,
#    u'layer_1': 6.816233545430607}},
#  u'epoch_166': {u'delta_angles': {u'layer_1': 5.800041687164896},
#   u'loss': 0.031210119705912368,
#   u'test_accuracy': 98.33,
#   u'weight_angles': {u'layer_0': 24.008923206191906,
#    u'layer_1': 6.7997694181906025}},
#  u'epoch_167': {u'delta_angles': {u'layer_1': 5.795664701108365},
#   u'loss': 0.030776900319588813,
#   u'test_accuracy': 98.33,
#   u'weight_angles': {u'layer_0': 23.89140136424632,
#    u'layer_1': 6.772125243125903}},
#  u'epoch_168': {u'delta_angles': {u'layer_1': 5.752209750348329},
#   u'loss': 0.030351613396159938,
#   u'test_accuracy': 98.34,
#   u'weight_angles': {u'layer_0': 23.74071999243408,
#    u'layer_1': 6.752685861981447}},
#  u'epoch_169': {u'delta_angles': {u'layer_1': 5.728486639259641},
#   u'loss': 0.02993411027560056,
#   u'test_accuracy': 98.34,
#   u'weight_angles': {u'layer_0': 23.61057381395202,
#    u'layer_1': 6.742265025504608}},
#  u'epoch_17': {u'delta_angles': {u'layer_1': 6.265377780535362},
#   u'loss': 0.5898915785801494,
#   u'test_accuracy': 92.11,
#   u'weight_angles': {u'layer_0': 64.94762586499756,
#    u'layer_1': 19.981561956770467}},
#  u'epoch_170': {u'delta_angles': {u'layer_1': 5.710555316342634},
#   u'loss': 0.029524357528407215,
#   u'test_accuracy': 98.34,
#   u'weight_angles': {u'layer_0': 23.478715629005222,
#    u'layer_1': 6.723730571318611}},
#  u'epoch_171': {u'delta_angles': {u'layer_1': 5.676706012023905},
#   u'loss': 0.02912212436439508,
#   u'test_accuracy': 98.35,
#   u'weight_angles': {u'layer_0': 23.38581822723552,
#    u'layer_1': 6.695547511597017}},
#  u'epoch_172': {u'delta_angles': {u'layer_1': 5.680704419126044},
#   u'loss': 0.028727297675843914,
#   u'test_accuracy': 98.35,
#   u'weight_angles': {u'layer_0': 23.28138293080318,
#    u'layer_1': 6.678613552817407}},
#  u'epoch_173': {u'delta_angles': {u'layer_1': 5.627571768290842},
#   u'loss': 0.02833976721976918,
#   u'test_accuracy': 98.36,
#   u'weight_angles': {u'layer_0': 23.19672006714209,
#    u'layer_1': 6.645969801092734}},
#  u'epoch_174': {u'delta_angles': {u'layer_1': 5.608653578282829},
#   u'loss': 0.02795924826837249,
#   u'test_accuracy': 98.36,
#   u'weight_angles': {u'layer_0': 23.09309084723097,
#    u'layer_1': 6.60963820443237}},
#  u'epoch_175': {u'delta_angles': {u'layer_1': 5.584340473328213},
#   u'loss': 0.027585693121654806,
#   u'test_accuracy': 98.36,
#   u'weight_angles': {u'layer_0': 23.000969985404783,
#    u'layer_1': 6.576300788939566}},
#  u'epoch_176': {u'delta_angles': {u'layer_1': 5.56954804240919},
#   u'loss': 0.02721880953448929,
#   u'test_accuracy': 98.36,
#   u'weight_angles': {u'layer_0': 22.920490833801523,
#    u'layer_1': 6.550636594649631}},
#  u'epoch_177': {u'delta_angles': {u'layer_1': 5.553317885545594},
#   u'loss': 0.02685871734301408,
#   u'test_accuracy': 98.37,
#   u'weight_angles': {u'layer_0': 22.792698061110894,
#    u'layer_1': 6.530293464894596}},
#  u'epoch_178': {u'delta_angles': {u'layer_1': 5.4951159806130025},
#   u'loss': 0.026505141722685997,
#   u'test_accuracy': 98.37,
#   u'weight_angles': {u'layer_0': 22.72809001627446,
#    u'layer_1': 6.506811122190056}},
#  u'epoch_179': {u'delta_angles': {u'layer_1': 5.494526801750969},
#   u'loss': 0.026157890505395506,
#   u'test_accuracy': 98.37,
#   u'weight_angles': {u'layer_0': 22.631401893604203,
#    u'layer_1': 6.490679886195321}},
#  u'epoch_18': {u'delta_angles': {u'layer_1': 6.847576054269843},
#   u'loss': 0.5734254694304347,
#   u'test_accuracy': 92.35,
#   u'weight_angles': {u'layer_0': 64.10838571969201,
#    u'layer_1': 19.517296072911773}},
#  u'epoch_180': {u'delta_angles': {u'layer_1': 5.464260917613363},
#   u'loss': 0.025817038769855832,
#   u'test_accuracy': 98.37,
#   u'weight_angles': {u'layer_0': 22.51609100315211,
#    u'layer_1': 6.471821136262817}},
#  u'epoch_181': {u'delta_angles': {u'layer_1': 5.46806914635465},
#   u'loss': 0.0254822577809388,
#   u'test_accuracy': 98.37,
#   u'weight_angles': {u'layer_0': 22.471954535221318,
#    u'layer_1': 6.4551229684991736}},
#  u'epoch_182': {u'delta_angles': {u'layer_1': 5.448874092870356},
#   u'loss': 0.02515348633621673,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 22.354173803382523,
#    u'layer_1': 6.4369831337320305}},
#  u'epoch_183': {u'delta_angles': {u'layer_1': 5.410146799831984},
#   u'loss': 0.024830614332187223,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 22.25167920087561,
#    u'layer_1': 6.40728126103564}},
#  u'epoch_184': {u'delta_angles': {u'layer_1': 5.4392224500697735},
#   u'loss': 0.024513461064262627,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 22.203043679158643,
#    u'layer_1': 6.390974479503335}},
#  u'epoch_185': {u'delta_angles': {u'layer_1': 5.413034870943347},
#   u'loss': 0.02420201554704433,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 22.103376234956922,
#    u'layer_1': 6.3661154677766945}},
#  u'epoch_186': {u'delta_angles': {u'layer_1': 5.355748574379331},
#   u'loss': 0.02389607840594367,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 22.039804765779703,
#    u'layer_1': 6.3456570531898455}},
#  u'epoch_187': {u'delta_angles': {u'layer_1': 5.327583244638161},
#   u'loss': 0.023595483749472308,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 21.933763168863408,
#    u'layer_1': 6.309040544263769}},
#  u'epoch_188': {u'delta_angles': {u'layer_1': 5.2961324312854385},
#   u'loss': 0.023300283250184562,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 21.82252413976525,
#    u'layer_1': 6.281317908192091}},
#  u'epoch_189': {u'delta_angles': {u'layer_1': 5.29031311221392},
#   u'loss': 0.023010196765984793,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 21.733534181330107,
#    u'layer_1': 6.25639700760853}},
#  u'epoch_19': {u'delta_angles': {u'layer_1': 7.708375650853228},
#   u'loss': 0.5568790865162019,
#   u'test_accuracy': 92.62,
#   u'weight_angles': {u'layer_0': 63.322977399215915,
#    u'layer_1': 18.749648424882476}},
#  u'epoch_190': {u'delta_angles': {u'layer_1': 5.267958982598261},
#   u'loss': 0.022725191088729762,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 21.64288378828542,
#    u'layer_1': 6.232863705083394}},
#  u'epoch_191': {u'delta_angles': {u'layer_1': 5.253216771143365},
#   u'loss': 0.022445239717364913,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 21.570295495396376,
#    u'layer_1': 6.2170002656624055}},
#  u'epoch_192': {u'delta_angles': {u'layer_1': 5.216842967135307},
#   u'loss': 0.02217011323003137,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 21.463583139490265,
#    u'layer_1': 6.202551017012776}},
#  u'epoch_193': {u'delta_angles': {u'layer_1': 5.181210571320296},
#   u'loss': 0.02189990655335985,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 21.389231811893453,
#    u'layer_1': 6.179284588492981}},
#  u'epoch_194': {u'delta_angles': {u'layer_1': 5.116754233750473},
#   u'loss': 0.021634328940834974,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 21.31037095111201,
#    u'layer_1': 6.165713732558806}},
#  u'epoch_195': {u'delta_angles': {u'layer_1': 5.123495256532897},
#   u'loss': 0.021373340280693202,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 21.206154797931458,
#    u'layer_1': 6.13402378318275}},
#  u'epoch_196': {u'delta_angles': {u'layer_1': 5.085444312725515},
#   u'loss': 0.021116810061293723,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 21.115072980135874,
#    u'layer_1': 6.11321553862378}},
#  u'epoch_197': {u'delta_angles': {u'layer_1': 5.066218896455927},
#   u'loss': 0.020864645210155554,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 21.056107323730707,
#    u'layer_1': 6.078729599366007}},
#  u'epoch_198': {u'delta_angles': {u'layer_1': 5.048000040063385},
#   u'loss': 0.02061680979322308,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 20.996069521934306,
#    u'layer_1': 6.060214731920403}},
#  u'epoch_199': {u'delta_angles': {u'layer_1': 5.029609374720261},
#   u'loss': 0.02037322953317242,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 20.9045712643338,
#    u'layer_1': 6.0348519334788895}},
#  u'epoch_2': {u'delta_angles': {u'layer_1': 36.22411171747195},
#   u'loss': 1.1793262637694268,
#   u'test_accuracy': 86.54,
#   u'weight_angles': {u'layer_0': 79.88139697626835,
#    u'layer_1': 47.25628443872452}},
#  u'epoch_20': {u'delta_angles': {u'layer_1': 8.688247306370236},
#   u'loss': 0.5402883290056066,
#   u'test_accuracy': 92.86,
#   u'weight_angles': {u'layer_0': 62.4208560989218,
#    u'layer_1': 18.24231978055219}},
#  u'epoch_200': {u'delta_angles': {u'layer_1': 5.0291407000387},
#   u'loss': 0.020133762846433034,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 20.85552165271952,
#    u'layer_1': 6.017126618495215}},
#  u'epoch_201': {u'delta_angles': {u'layer_1': 5.01701173749453},
#   u'loss': 0.019898401315808723,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 20.775347045950344,
#    u'layer_1': 5.986222125701155}},
#  u'epoch_202': {u'delta_angles': {u'layer_1': 4.988863919099596},
#   u'loss': 0.01966698374499197,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 20.695244279714046,
#    u'layer_1': 5.969118237920335}},
#  u'epoch_203': {u'delta_angles': {u'layer_1': 4.947259304954551},
#   u'loss': 0.019439406051101976,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 20.61412051790675,
#    u'layer_1': 5.950899063014921}},
#  u'epoch_204': {u'delta_angles': {u'layer_1': 4.942216856204688},
#   u'loss': 0.019215614866460364,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 20.563914127711403,
#    u'layer_1': 5.933494195467071}},
#  u'epoch_205': {u'delta_angles': {u'layer_1': 4.922295896266982},
#   u'loss': 0.018995568277623283,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 20.49567714894672,
#    u'layer_1': 5.9039052194601345}},
#  u'epoch_206': {u'delta_angles': {u'layer_1': 4.932844451089287},
#   u'loss': 0.0187791996405038,
#   u'test_accuracy': 98.38,
#   u'weight_angles': {u'layer_0': 20.425832161740015,
#    u'layer_1': 5.875548269143694}},
#  u'epoch_207': {u'delta_angles': {u'layer_1': 4.938741298556974},
#   u'loss': 0.018566429070245305,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 20.390112140874994,
#    u'layer_1': 5.860163830847039}},
#  u'epoch_208': {u'delta_angles': {u'layer_1': 4.917402956608146},
#   u'loss': 0.01835719083020216,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 20.312718586584456,
#    u'layer_1': 5.843120983071835}},
#  u'epoch_209': {u'delta_angles': {u'layer_1': 4.8964975550749665},
#   u'loss': 0.018151383692775462,
#   u'test_accuracy': 98.39,
#   u'weight_angles': {u'layer_0': 20.222208198667538,
#    u'layer_1': 5.81265505757379}},
#  u'epoch_21': {u'delta_angles': {u'layer_1': 9.628607356560988},
#   u'loss': 0.5237964488183503,
#   u'test_accuracy': 93.08,
#   u'weight_angles': {u'layer_0': 61.87938826246906,
#    u'layer_1': 17.74084799792652}},
#  u'epoch_210': {u'delta_angles': {u'layer_1': 4.878049107539412},
#   u'loss': 0.01794894512372857,
#   u'test_accuracy': 98.4,
#   u'weight_angles': {u'layer_0': 20.190331715113963,
#    u'layer_1': 5.79109698878819}},
#  u'epoch_211': {u'delta_angles': {u'layer_1': 4.844012623668098},
#   u'loss': 0.017749835014154308,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 20.124119819279127,
#    u'layer_1': 5.779227695664353}},
#  u'epoch_212': {u'delta_angles': {u'layer_1': 4.845943609825479},
#   u'loss': 0.01755396291359975,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 20.073366276112818,
#    u'layer_1': 5.754063063612688}},
#  u'epoch_213': {u'delta_angles': {u'layer_1': 4.816743404684636},
#   u'loss': 0.017361221462354148,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 20.007909184363267,
#    u'layer_1': 5.732569546951432}},
#  u'epoch_214': {u'delta_angles': {u'layer_1': 4.788436373389751},
#   u'loss': 0.017171584568276128,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 19.934665326575725,
#    u'layer_1': 5.7132363863960425}},
#  u'epoch_215': {u'delta_angles': {u'layer_1': 4.7788985019659025},
#   u'loss': 0.016985000515622604,
#   u'test_accuracy': 98.4,
#   u'weight_angles': {u'layer_0': 19.894655645251607,
#    u'layer_1': 5.702580798622705}},
#  u'epoch_216': {u'delta_angles': {u'layer_1': 4.769067156780885},
#   u'loss': 0.016801400292099925,
#   u'test_accuracy': 98.4,
#   u'weight_angles': {u'layer_0': 19.815855261373287,
#    u'layer_1': 5.6853554053170905}},
#  u'epoch_217': {u'delta_angles': {u'layer_1': 4.772335281224468},
#   u'loss': 0.016620725822621387,
#   u'test_accuracy': 98.4,
#   u'weight_angles': {u'layer_0': 19.718726790851875,
#    u'layer_1': 5.665616798624804}},
#  u'epoch_218': {u'delta_angles': {u'layer_1': 4.76994345847806},
#   u'loss': 0.016442953992283828,
#   u'test_accuracy': 98.4,
#   u'weight_angles': {u'layer_0': 19.640017334623096,
#    u'layer_1': 5.656261228127335}},
#  u'epoch_219': {u'delta_angles': {u'layer_1': 4.739007975941189},
#   u'loss': 0.01626798615207443,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 19.58627366467732,
#    u'layer_1': 5.636005952995514}},
#  u'epoch_22': {u'delta_angles': {u'layer_1': 10.40764986599811},
#   u'loss': 0.5075562254445586,
#   u'test_accuracy': 93.26,
#   u'weight_angles': {u'layer_0': 61.260240186658486,
#    u'layer_1': 17.355246745253186}},
#  u'epoch_220': {u'delta_angles': {u'layer_1': 4.730136599893335},
#   u'loss': 0.01609572805175988,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 19.52640005463028,
#    u'layer_1': 5.62742762920353}},
#  u'epoch_221': {u'delta_angles': {u'layer_1': 4.6971601103678475},
#   u'loss': 0.01592621768462045,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 19.45261154584097,
#    u'layer_1': 5.610674382304697}},
#  u'epoch_222': {u'delta_angles': {u'layer_1': 4.652704417304034},
#   u'loss': 0.01575930543319758,
#   u'test_accuracy': 98.42,
#   u'weight_angles': {u'layer_0': 19.379851982819787,
#    u'layer_1': 5.594356143588265}},
#  u'epoch_223': {u'delta_angles': {u'layer_1': 4.663444503788599},
#   u'loss': 0.015595020042045748,
#   u'test_accuracy': 98.42,
#   u'weight_angles': {u'layer_0': 19.330207511363007,
#    u'layer_1': 5.582587181870742}},
#  u'epoch_224': {u'delta_angles': {u'layer_1': 4.655573965780074},
#   u'loss': 0.01543322139081131,
#   u'test_accuracy': 98.42,
#   u'weight_angles': {u'layer_0': 19.2581489087905,
#    u'layer_1': 5.567802311932796}},
#  u'epoch_225': {u'delta_angles': {u'layer_1': 4.6570537661795255},
#   u'loss': 0.015273954195113503,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 19.17874656161009,
#    u'layer_1': 5.555023772454769}},
#  u'epoch_226': {u'delta_angles': {u'layer_1': 4.637387356641274},
#   u'loss': 0.015117120103942778,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 19.09370544115447,
#    u'layer_1': 5.545024029821327}},
#  u'epoch_227': {u'delta_angles': {u'layer_1': 4.622578889815418},
#   u'loss': 0.014962694638961084,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 18.98592456711086,
#    u'layer_1': 5.526523991756288}},
#  u'epoch_228': {u'delta_angles': {u'layer_1': 4.613094060615912},
#   u'loss': 0.014810591474352442,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 18.930709100838587,
#    u'layer_1': 5.511961141796318}},
#  u'epoch_229': {u'delta_angles': {u'layer_1': 4.589814652093912},
#   u'loss': 0.01466076682837375,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 18.86844504056281,
#    u'layer_1': 5.493968468965442}},
#  u'epoch_23': {u'delta_angles': {u'layer_1': 11.172141786263952},
#   u'loss': 0.4916832717297484,
#   u'test_accuracy': 93.46,
#   u'weight_angles': {u'layer_0': 60.655049460614705,
#    u'layer_1': 17.019721007702383}},
#  u'epoch_230': {u'delta_angles': {u'layer_1': 4.579837344703327},
#   u'loss': 0.014513185550954391,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 18.82047652196689,
#    u'layer_1': 5.4752871434423716}},
#  u'epoch_231': {u'delta_angles': {u'layer_1': 4.583550861816882},
#   u'loss': 0.014367841338817806,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 18.77076507576648,
#    u'layer_1': 5.4603938106545264}},
#  u'epoch_232': {u'delta_angles': {u'layer_1': 4.593603028071536},
#   u'loss': 0.01422465103692322,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 18.734857562578327,
#    u'layer_1': 5.4420721671827685}},
#  u'epoch_233': {u'delta_angles': {u'layer_1': 4.574486069312289},
#   u'loss': 0.014083595107074744,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 18.676742735060625,
#    u'layer_1': 5.428664484113546}},
#  u'epoch_234': {u'delta_angles': {u'layer_1': 4.560482047385945},
#   u'loss': 0.01394462032191013,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 18.61656280257127,
#    u'layer_1': 5.41597297274974}},
#  u'epoch_235': {u'delta_angles': {u'layer_1': 4.532828672589351},
#   u'loss': 0.013807701253112134,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 18.556411814299597,
#    u'layer_1': 5.396032265887735}},
#  u'epoch_236': {u'delta_angles': {u'layer_1': 4.516702588519814},
#   u'loss': 0.013672784734912508,
#   u'test_accuracy': 98.42,
#   u'weight_angles': {u'layer_0': 18.492255335742072,
#    u'layer_1': 5.378928185611313}},
#  u'epoch_237': {u'delta_angles': {u'layer_1': 4.519989887750514},
#   u'loss': 0.013539831626666004,
#   u'test_accuracy': 98.42,
#   u'weight_angles': {u'layer_0': 18.42287012574801,
#    u'layer_1': 5.368589451035642}},
#  u'epoch_238': {u'delta_angles': {u'layer_1': 4.502214818058555},
#   u'loss': 0.013408833224157351,
#   u'test_accuracy': 98.42,
#   u'weight_angles': {u'layer_0': 18.360394914890993,
#    u'layer_1': 5.352377207447623}},
#  u'epoch_239': {u'delta_angles': {u'layer_1': 4.504046309537691},
#   u'loss': 0.013279718337180066,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 18.30057027381536,
#    u'layer_1': 5.338868370273458}},
#  u'epoch_24': {u'delta_angles': {u'layer_1': 11.646581192632821},
#   u'loss': 0.4762604846320059,
#   u'test_accuracy': 93.64,
#   u'weight_angles': {u'layer_0': 60.5708274244723,
#    u'layer_1': 16.59467540054343}},
#  u'epoch_240': {u'delta_angles': {u'layer_1': 4.50573041878464},
#   u'loss': 0.013152471927672093,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 18.232126917982335,
#    u'layer_1': 5.322020198701945}},
#  u'epoch_241': {u'delta_angles': {u'layer_1': 4.5005555410046325},
#   u'loss': 0.013027088461494397,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 18.159631102850923,
#    u'layer_1': 5.3138178886421334}},
#  u'epoch_242': {u'delta_angles': {u'layer_1': 4.484569419951955},
#   u'loss': 0.012903443928383601,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 18.13541716476144,
#    u'layer_1': 5.307359109093784}},
#  u'epoch_243': {u'delta_angles': {u'layer_1': 4.480039858564377},
#   u'loss': 0.012781586197582783,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 18.059780972618956,
#    u'layer_1': 5.294073187797425}},
#  u'epoch_244': {u'delta_angles': {u'layer_1': 4.45729405789208},
#   u'loss': 0.012661476697819777,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 17.995486839524887,
#    u'layer_1': 5.277918166786238}},
#  u'epoch_245': {u'delta_angles': {u'layer_1': 4.423355964512372},
#   u'loss': 0.012543052524130946,
#   u'test_accuracy': 98.41,
#   u'weight_angles': {u'layer_0': 17.96352601483603,
#    u'layer_1': 5.260383160621365}},
#  u'epoch_246': {u'delta_angles': {u'layer_1': 4.393135594645631},
#   u'loss': 0.012426275583252376,
#   u'test_accuracy': 98.42,
#   u'weight_angles': {u'layer_0': 17.89738287122235,
#    u'layer_1': 5.242821672604858}},
#  u'epoch_247': {u'delta_angles': {u'layer_1': 4.379130480301107},
#   u'loss': 0.012311159254622485,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.818419261543962,
#    u'layer_1': 5.236144396358611}},
#  u'epoch_248': {u'delta_angles': {u'layer_1': 4.377114726072661},
#   u'loss': 0.012197657604175705,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.763466018505923,
#    u'layer_1': 5.222799075348555}},
#  u'epoch_249': {u'delta_angles': {u'layer_1': 4.362021452683649},
#   u'loss': 0.012085760749112155,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.716115419420678,
#    u'layer_1': 5.208897379428982}},
#  u'epoch_25': {u'delta_angles': {u'layer_1': 12.047874033353766},
#   u'loss': 0.4613366964598056,
#   u'test_accuracy': 93.8,
#   u'weight_angles': {u'layer_0': 59.99461045705174,
#    u'layer_1': 16.225907395394856}},
#  u'epoch_250': {u'delta_angles': {u'layer_1': 4.34976625747266},
#   u'loss': 0.011975407385181774,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.656860998029146,
#    u'layer_1': 5.196197422151618}},
#  u'epoch_251': {u'delta_angles': {u'layer_1': 4.309277977264787},
#   u'loss': 0.011866589862962606,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.608430181032276,
#    u'layer_1': 5.181384127620779}},
#  u'epoch_252': {u'delta_angles': {u'layer_1': 4.300707131178171},
#   u'loss': 0.011759285276185905,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.539498127992655,
#    u'layer_1': 5.169709641270292}},
#  u'epoch_253': {u'delta_angles': {u'layer_1': 4.2881103766525035},
#   u'loss': 0.011653485234447791,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.476581192079813,
#    u'layer_1': 5.152130170182044}},
#  u'epoch_254': {u'delta_angles': {u'layer_1': 4.297579006769082},
#   u'loss': 0.011549135327331253,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.437312294797124,
#    u'layer_1': 5.139891551611272}},
#  u'epoch_255': {u'delta_angles': {u'layer_1': 4.285311682847921},
#   u'loss': 0.011446206711079807,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.394992835636707,
#    u'layer_1': 5.130843908852993}},
#  u'epoch_256': {u'delta_angles': {u'layer_1': 4.253755633626577},
#   u'loss': 0.01134468570293149,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.354644787881856,
#    u'layer_1': 5.113136325930474}},
#  u'epoch_257': {u'delta_angles': {u'layer_1': 4.265009347677561},
#   u'loss': 0.011244541501929753,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.321592152146685,
#    u'layer_1': 5.099990030158166}},
#  u'epoch_258': {u'delta_angles': {u'layer_1': 4.269275771963024},
#   u'loss': 0.011145769373496133,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.262702361822566,
#    u'layer_1': 5.093023693563168}},
#  u'epoch_259': {u'delta_angles': {u'layer_1': 4.253266434238328},
#   u'loss': 0.011048357160818503,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.20271941966696,
#    u'layer_1': 5.078668496313068}},
#  u'epoch_26': {u'delta_angles': {u'layer_1': 12.373963414309227},
#   u'loss': 0.44692760040233287,
#   u'test_accuracy': 93.97,
#   u'weight_angles': {u'layer_0': 59.657770638986314,
#    u'layer_1': 15.915834218710057}},
#  u'epoch_260': {u'delta_angles': {u'layer_1': 4.2457491832780745},
#   u'loss': 0.0109522552429955,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.18204255535498,
#    u'layer_1': 5.06039537369431}},
#  u'epoch_261': {u'delta_angles': {u'layer_1': 4.231495852475706},
#   u'loss': 0.010857455721006918,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.08263621681092,
#    u'layer_1': 5.044895929637117}},
#  u'epoch_262': {u'delta_angles': {u'layer_1': 4.232022802814865},
#   u'loss': 0.010763936145437204,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 17.03212144715258,
#    u'layer_1': 5.029479954808892}},
#  u'epoch_263': {u'delta_angles': {u'layer_1': 4.218017370100142},
#   u'loss': 0.010671644965720034,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.974687879241564,
#    u'layer_1': 5.012468965675474}},
#  u'epoch_264': {u'delta_angles': {u'layer_1': 4.205479737552077},
#   u'loss': 0.010580597583578561,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.929731367004326,
#    u'layer_1': 4.999306771639076}},
#  u'epoch_265': {u'delta_angles': {u'layer_1': 4.19785644052775},
#   u'loss': 0.010490752311071798,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.9132376949655,
#    u'layer_1': 4.995731505720485}},
#  u'epoch_266': {u'delta_angles': {u'layer_1': 4.198090673048316},
#   u'loss': 0.010402104078427463,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.851055707199897,
#    u'layer_1': 4.976311531275943}},
#  u'epoch_267': {u'delta_angles': {u'layer_1': 4.171785299699486},
#   u'loss': 0.01031461198736165,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.799663948249272,
#    u'layer_1': 4.960337893992123}},
#  u'epoch_268': {u'delta_angles': {u'layer_1': 4.1472325371320675},
#   u'loss': 0.010228263695156586,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.739771187800585,
#    u'layer_1': 4.939021770877923}},
#  u'epoch_269': {u'delta_angles': {u'layer_1': 4.109512752527604},
#   u'loss': 0.010143061618766226,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.689946692123986,
#    u'layer_1': 4.926308472725288}},
#  u'epoch_27': {u'delta_angles': {u'layer_1': 12.734556863333003},
#   u'loss': 0.4330388897297812,
#   u'test_accuracy': 94.24,
#   u'weight_angles': {u'layer_0': 59.33229737668478,
#    u'layer_1': 15.735888333087454}},
#  u'epoch_270': {u'delta_angles': {u'layer_1': 4.1027283705298165},
#   u'loss': 0.01005896147609999,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 16.637962075608755,
#    u'layer_1': 4.912015942164706}},
#  u'epoch_271': {u'delta_angles': {u'layer_1': 4.097400124100087},
#   u'loss': 0.00997594007190709,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.615969313564726,
#    u'layer_1': 4.891038868663701}},
#  u'epoch_272': {u'delta_angles': {u'layer_1': 4.074973892975367},
#   u'loss': 0.009893978809270508,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.595269115755187,
#    u'layer_1': 4.877592304417748}},
#  u'epoch_273': {u'delta_angles': {u'layer_1': 4.062591137032491},
#   u'loss': 0.00981307860249337,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.543542696393157,
#    u'layer_1': 4.865320223494324}},
#  u'epoch_274': {u'delta_angles': {u'layer_1': 4.059713850927948},
#   u'loss': 0.009733222939744154,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.499144930639588,
#    u'layer_1': 4.847377725292701}},
#  u'epoch_275': {u'delta_angles': {u'layer_1': 4.063489465206458},
#   u'loss': 0.009654377757205764,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.46864970998584,
#    u'layer_1': 4.832682605130417}},
#  u'epoch_276': {u'delta_angles': {u'layer_1': 4.050092592469649},
#   u'loss': 0.009576546338590421,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.42402491994894,
#    u'layer_1': 4.817658213209696}},
#  u'epoch_277': {u'delta_angles': {u'layer_1': 4.053457999302675},
#   u'loss': 0.009499687060118825,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.38348361870874,
#    u'layer_1': 4.8119561118239895}},
#  u'epoch_278': {u'delta_angles': {u'layer_1': 4.067765822525875},
#   u'loss': 0.009423811570408879,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.349633001526673,
#    u'layer_1': 4.8058582972891735}},
#  u'epoch_279': {u'delta_angles': {u'layer_1': 4.081425994944684},
#   u'loss': 0.00934887782153564,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.319950915342318,
#    u'layer_1': 4.798561756953877}},
#  u'epoch_28': {u'delta_angles': {u'layer_1': 12.962977664182255},
#   u'loss': 0.4196883331488519,
#   u'test_accuracy': 94.43,
#   u'weight_angles': {u'layer_0': 59.19903111649481,
#    u'layer_1': 15.611184655059812}},
#  u'epoch_280': {u'delta_angles': {u'layer_1': 4.058775111844047},
#   u'loss': 0.009274864573691477,
#   u'test_accuracy': 98.42,
#   u'weight_angles': {u'layer_0': 16.294062345874607,
#    u'layer_1': 4.786508346707538}},
#  u'epoch_281': {u'delta_angles': {u'layer_1': 4.048031491161789},
#   u'loss': 0.009201782584224695,
#   u'test_accuracy': 98.42,
#   u'weight_angles': {u'layer_0': 16.253059438889885,
#    u'layer_1': 4.774960402064364}},
#  u'epoch_282': {u'delta_angles': {u'layer_1': 4.06189245472949},
#   u'loss': 0.009129615680355108,
#   u'test_accuracy': 98.42,
#   u'weight_angles': {u'layer_0': 16.198822948558238,
#    u'layer_1': 4.762837622046915}},
#  u'epoch_283': {u'delta_angles': {u'layer_1': 4.055232762174889},
#   u'loss': 0.009058313197231266,
#   u'test_accuracy': 98.42,
#   u'weight_angles': {u'layer_0': 16.17260198784875,
#    u'layer_1': 4.757565291089164}},
#  u'epoch_284': {u'delta_angles': {u'layer_1': 4.042961839363889},
#   u'loss': 0.008987898187725054,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.125832931027617,
#    u'layer_1': 4.743185324688559}},
#  u'epoch_285': {u'delta_angles': {u'layer_1': 4.05138086200008},
#   u'loss': 0.008918338473378612,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.090990360311437,
#    u'layer_1': 4.7358540054872}},
#  u'epoch_286': {u'delta_angles': {u'layer_1': 4.032174177142572},
#   u'loss': 0.008849634161311874,
#   u'test_accuracy': 98.43,
#   u'weight_angles': {u'layer_0': 16.030929016629344,
#    u'layer_1': 4.723552269668624}},
#  u'epoch_287': {u'delta_angles': {u'layer_1': 4.006501744531527},
#   u'loss': 0.008781760875620472,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.989042276255939,
#    u'layer_1': 4.705502880646948}},
#  u'epoch_288': {u'delta_angles': {u'layer_1': 3.9917503323106245},
#   u'loss': 0.008714699868047033,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.949255282208437,
#    u'layer_1': 4.697382620218024}},
#  u'epoch_289': {u'delta_angles': {u'layer_1': 3.9926427510703597},
#   u'loss': 0.008648442579777314,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.91897875040354,
#    u'layer_1': 4.684904484250945}},
#  u'epoch_29': {u'delta_angles': {u'layer_1': 13.204824751998807},
#   u'loss': 0.40688883416606936,
#   u'test_accuracy': 94.58,
#   u'weight_angles': {u'layer_0': 58.51424870061359,
#    u'layer_1': 15.475059959855074}},
#  u'epoch_290': {u'delta_angles': {u'layer_1': 3.9804918973446313},
#   u'loss': 0.00858297876982814,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.867387029726734,
#    u'layer_1': 4.6766594636054535}},
#  u'epoch_291': {u'delta_angles': {u'layer_1': 3.9879717363802527},
#   u'loss': 0.008518295364216295,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.828653240188526,
#    u'layer_1': 4.6646689263218795}},
#  u'epoch_292': {u'delta_angles': {u'layer_1': 3.9638325351305848},
#   u'loss': 0.00845437565636468,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.77429100684405,
#    u'layer_1': 4.648497577820916}},
#  u'epoch_293': {u'delta_angles': {u'layer_1': 3.939603261221201},
#   u'loss': 0.008391205624744226,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.730969272187137,
#    u'layer_1': 4.637302103243889}},
#  u'epoch_294': {u'delta_angles': {u'layer_1': 3.9294407225345567},
#   u'loss': 0.00832878584837002,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.696961285265711,
#    u'layer_1': 4.632320846759074}},
#  u'epoch_295': {u'delta_angles': {u'layer_1': 3.914698700745627},
#   u'loss': 0.00826709854999592,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.66078956816705,
#    u'layer_1': 4.6195940715819015}},
#  u'epoch_296': {u'delta_angles': {u'layer_1': 3.903715807548644},
#   u'loss': 0.00820614218712932,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.62186941802061,
#    u'layer_1': 4.608984882645698}},
#  u'epoch_297': {u'delta_angles': {u'layer_1': 3.9056979510116947},
#   u'loss': 0.00814587129417346,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.58055247607709,
#    u'layer_1': 4.60571943192305}},
#  u'epoch_298': {u'delta_angles': {u'layer_1': 3.903507731276452},
#   u'loss': 0.008086300048837982,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.549367861907504,
#    u'layer_1': 4.596652162528751}},
#  u'epoch_299': {u'delta_angles': {u'layer_1': 3.8892681306336696},
#   u'loss': 0.008027409340078616,
#   u'test_accuracy': 98.44,
#   u'weight_angles': {u'layer_0': 15.492732478862704,
#    u'layer_1': 4.582521108832311}},
#  u'epoch_3': {u'delta_angles': {u'layer_1': 29.67279130738177},
#   u'loss': 1.0164669303473264,
#   u'test_accuracy': 87.94,
#   u'weight_angles': {u'layer_0': 78.33798761439999,
#    u'layer_1': 41.99473817346879}},
#  u'epoch_30': {u'delta_angles': {u'layer_1': 13.60723724214435},
#   u'loss': 0.3946178512779172,
# ...
#  u'epoch_391': {u'delta_angles': {u'layer_1': 3.2776430291040097},
#   u'loss': 0.004563258103843561,
#   u'test_accuracy': 98.48,
#   u'weight_angles': {u'layer_0': 12.946874731442007,
#    u'layer_1': 3.8450350866914933}},
#  u'epoch_392': {u'delta_angles': {u'layer_1': 3.2669200317964755},
#   u'loss': 0.004539600891093116,
#   u'test_accuracy': 98.48,
#   u'weight_angles': {u'layer_0': 12.927413186321484,
#    u'layer_1': 3.835572964400205}},
#  u'epoch_393': {u'delta_angles': {u'layer_1': 3.260777601387139},
#   u'loss': 0.004516139848042502,
#   u'test_accuracy': 98.48,
#   u'weight_angles': {u'layer_0': 12.921164478877266,
#    u'layer_1': 3.829304473763812}},
#  u'epoch_394': {u'delta_angles': {u'layer_1': 3.2506356895418165},
#   u'loss': 0.004492876908259565,
#   u'test_accuracy': 98.48,
#   u'weight_angles': {u'layer_0': 12.899501062684775,
#    u'layer_1': 3.8202019717122466}},
#  u'epoch_395': {u'delta_angles': {u'layer_1': 3.248544441990352},
#   u'loss': 0.004469801010969167,
#   u'test_accuracy': 98.48,
#   u'weight_angles': {u'layer_0': 12.879561792294929,
#    u'layer_1': 3.8170210710916153}},
#  u'epoch_396': {u'delta_angles': {u'layer_1': 3.2415683667587114},
#   u'loss': 0.004446917637562411,
#   u'test_accuracy': 98.48,
#   u'weight_angles': {u'layer_0': 12.847899803398615,
#    u'layer_1': 3.8109935960965986}},
#  u'epoch_397': {u'delta_angles': {u'layer_1': 3.2242769519988017},
#   u'loss': 0.0044242214504934835,
#   u'test_accuracy': 98.49,
#   u'weight_angles': {u'layer_0': 12.818513440640391,
#    u'layer_1': 3.8024534025074197}},
#  u'epoch_398': {u'delta_angles': {u'layer_1': 3.2254720411143896},
#   u'loss': 0.004401711571610944,
#   u'test_accuracy': 98.49,
#   u'weight_angles': {u'layer_0': 12.802895940330673,
#    u'layer_1': 3.793739069449895}},
#  u'epoch_399': {u'delta_angles': {u'layer_1': 3.2131431715331407},
#   u'loss': 0.004379383049279019,
#   u'test_accuracy': 98.49,
#   u'weight_angles': {u'layer_0': 12.786058361545562,
#    u'layer_1': 3.787535922455258}},
#  u'epoch_4': {u'delta_angles': {u'layer_1': 26.327558367219364},
#   u'loss': 0.9191052297011619,
#   u'test_accuracy': 88.48,
#   u'weight_angles': {u'layer_0': 77.18321807609404,
#    u'layer_1': 37.97536790363903}},
#  u'epoch_40': {u'delta_angles': {u'layer_1': 13.98337728504457},
#   u'loss': 0.2968914221728146,
#   u'test_accuracy': 95.93,
#   u'weight_angles': {u'layer_0': 53.128114273451956,
#    u'layer_1': 13.968061751055178}},
#  u'epoch_41': {u'delta_angles': {u'layer_1': 13.961885773962694},
#   u'loss': 0.2891751287929641,
#   u'test_accuracy': 96.0,
#   u'weight_angles': {u'layer_0': 52.565850430594715,
#    u'layer_1': 13.811768435379866}},
#  u'epoch_42': {u'delta_angles': {u'layer_1': 14.045618441315247},
#   u'loss': 0.2817591194934255,
#   u'test_accuracy': 96.04,
#   u'weight_angles': {u'layer_0': 52.269049199273084,
#    u'layer_1': 13.764720625894192}},
#  u'epoch_43': {u'delta_angles': {u'layer_1': 13.994958271918408},
#   u'loss': 0.27462542096801534,
#   u'test_accuracy': 96.18,
#   u'weight_angles': {u'layer_0': 51.86677990949186,
#    u'layer_1': 13.598484191747293}},
#  u'epoch_44': {u'delta_angles': {u'layer_1': 13.82276693943252},
#   u'loss': 0.26775717656916265,
#   u'test_accuracy': 96.21,
#   u'weight_angles': {u'layer_0': 51.776869861669304,
#    u'layer_1': 13.476873372216065}},
#  u'epoch_45': {u'delta_angles': {u'layer_1': 13.839250850332917},
#   u'loss': 0.2611450538909287,
#   u'test_accuracy': 96.31,
#   u'weight_angles': {u'layer_0': 51.45035877383318,
#    u'layer_1': 13.398148262635884}},
#  u'epoch_46': {u'delta_angles': {u'layer_1': 13.662951276536532},
#   u'loss': 0.2547760144009718,
#   u'test_accuracy': 96.39,
#   u'weight_angles': {u'layer_0': 51.19551071281094,
#    u'layer_1': 13.268398007002599}},
#  u'epoch_47': {u'delta_angles': {u'layer_1': 13.563278961346441},
#   u'loss': 0.24863759114688716,
#   u'test_accuracy': 96.46,
#   u'weight_angles': {u'layer_0': 50.791231368285125,
#    u'layer_1': 13.276671312349853}},
#  u'epoch_48': {u'delta_angles': {u'layer_1': 13.454146132481455},
#   u'loss': 0.24271837552598916,
#   u'test_accuracy': 96.46,
#   u'weight_angles': {u'layer_0': 50.145315651798214,
#    u'layer_1': 13.145425276079038}},
#  u'epoch_49': {u'delta_angles': {u'layer_1': 13.445413155551682},
#   u'loss': 0.2370027297070983,
#   u'test_accuracy': 96.51,
#   u'weight_angles': {u'layer_0': 49.79326629694689,
#    u'layer_1': 13.093580408987817}},
#  u'epoch_5': {u'delta_angles': {u'layer_1': 23.56853379930911},
#   u'loss': 0.8549988160585282,
#   u'test_accuracy': 89.15,
#   u'weight_angles': {u'layer_0': 76.07602294313028,
#    u'layer_1': 34.862039154940305}},
#  u'epoch_50': {u'delta_angles': {u'layer_1': 13.441839535874129},
#   u'loss': 0.23148716023572008,
#   u'test_accuracy': 96.58,
#   u'weight_angles': {u'layer_0': 49.4624797954273,
#    u'layer_1': 12.922838384875206}},
#  u'epoch_51': {u'delta_angles': {u'layer_1': 13.337514567651299},
#   u'loss': 0.22615731811145742,
#   u'test_accuracy': 96.61,
#   u'weight_angles': {u'layer_0': 49.0297600266471,
#    u'layer_1': 12.748995443779256}},
#  u'epoch_52': {u'delta_angles': {u'layer_1': 13.274573699962506},
#   u'loss': 0.22100861570500546,
#   u'test_accuracy': 96.65,
#   u'weight_angles': {u'layer_0': 48.72465747616938,
#    u'layer_1': 12.70605887906119}},
#  u'epoch_53': {u'delta_angles': {u'layer_1': 13.037633427490864},
#   u'loss': 0.2160329533295774,
#   u'test_accuracy': 96.7,
#   u'weight_angles': {u'layer_0': 48.140427301768945,
#    u'layer_1': 12.61302482118371}},
#  u'epoch_54': {u'delta_angles': {u'layer_1': 12.793833032178787},
#   u'loss': 0.21122145396557593,
#   u'test_accuracy': 96.77,
#   u'weight_angles': {u'layer_0': 47.60328718548541,
#    u'layer_1': 12.47190098077487}},
#  u'epoch_55': {u'delta_angles': {u'layer_1': 12.850870988785244},
#   u'loss': 0.2065644936479217,
#   u'test_accuracy': 96.8,
#   u'weight_angles': {u'layer_0': 47.34494347695493,
#    u'layer_1': 12.436962805228134}},
#  u'epoch_56': {u'delta_angles': {u'layer_1': 12.707486684058123},
#   u'loss': 0.20205853033613477,
#   u'test_accuracy': 96.88,
#   u'weight_angles': {u'layer_0': 47.042455833986516,
#    u'layer_1': 12.306300588840433}},
#  u'epoch_57': {u'delta_angles': {u'layer_1': 12.691532493603},
#   u'loss': 0.19769646736671084,
#   u'test_accuracy': 96.93,
#   u'weight_angles': {u'layer_0': 46.327740399498104,
#    u'layer_1': 12.195972935344503}},
#  u'epoch_58': {u'delta_angles': {u'layer_1': 12.657189265669876},
#   u'loss': 0.19347146852730923,
#   u'test_accuracy': 96.95,
#   u'weight_angles': {u'layer_0': 45.80977746027124,
#    u'layer_1': 12.047513154139493}},
#  u'epoch_59': {u'delta_angles': {u'layer_1': 12.634264645404818},
#   u'loss': 0.18937592000624745,
#   u'test_accuracy': 96.97,
#   u'weight_angles': {u'layer_0': 45.4603460343606,
#    u'layer_1': 11.906358567597996}},
#  u'epoch_6': {u'delta_angles': {u'layer_1': 21.473506012927132},
#   u'loss': 0.8096710161621908,
#   u'test_accuracy': 89.59,
#   u'weight_angles': {u'layer_0': 75.11642237209574,
#    u'layer_1': 32.509607077668775}},
#  u'epoch_60': {u'delta_angles': {u'layer_1': 12.43329381713218},
#   u'loss': 0.18540494385050837,
#   u'test_accuracy': 96.99,
#   u'weight_angles': {u'layer_0': 45.08614894451392,
#    u'layer_1': 11.799453125274889}},
#  u'epoch_61': {u'delta_angles': {u'layer_1': 12.458868943051874},
#   u'loss': 0.18155402825791658,
#   u'test_accuracy': 97.01,
#   u'weight_angles': {u'layer_0': 44.628902495528386,
#    u'layer_1': 11.700343475358755}},
#  u'epoch_62': {u'delta_angles': {u'layer_1': 12.366658084489382},
#   u'loss': 0.17781839142867148,
#   u'test_accuracy': 97.02,
#   u'weight_angles': {u'layer_0': 44.17642916838219,
#    u'layer_1': 11.597322449683453}},
#  u'epoch_63': {u'delta_angles': {u'layer_1': 12.337977982866219},
#   u'loss': 0.1741904740702804,
#   u'test_accuracy': 97.03,
#   u'weight_angles': {u'layer_0': 43.682280612802536,
#    u'layer_1': 11.575380739244117}},
#  u'epoch_64': {u'delta_angles': {u'layer_1': 12.235892213366123},
#   u'loss': 0.17066758458303155,
#   u'test_accuracy': 97.07,
#   u'weight_angles': {u'layer_0': 43.32125514495467,
#    u'layer_1': 11.487286048319827}},
#  u'epoch_65': {u'delta_angles': {u'layer_1': 12.130660935655404},
#   u'loss': 0.16724580257382846,
#   u'test_accuracy': 97.15,
#   u'weight_angles': {u'layer_0': 43.042807247621305,
#    u'layer_1': 11.387989333045606}},
#  u'epoch_66': {u'delta_angles': {u'layer_1': 12.108321684544343},
#   u'loss': 0.16391885153402386,
#   u'test_accuracy': 97.21,
#   u'weight_angles': {u'layer_0': 42.60209838515927,
#    u'layer_1': 11.313691098015067}},
#  u'epoch_67': {u'delta_angles': {u'layer_1': 12.11394963450767},
#   u'loss': 0.1606839046300274,
#   u'test_accuracy': 97.24,
#   u'weight_angles': {u'layer_0': 42.22342121332858,
#    u'layer_1': 11.26458626353796}},
#  u'epoch_68': {u'delta_angles': {u'layer_1': 11.944153965466692},
#   u'loss': 0.15753656802964267,
#   u'test_accuracy': 97.26,
#   u'weight_angles': {u'layer_0': 41.89170783132663,
#    u'layer_1': 11.203438027806715}},
#  u'epoch_69': {u'delta_angles': {u'layer_1': 11.908180840178147},
#   u'loss': 0.1544733003896605,
#   u'test_accuracy': 97.31,
#   u'weight_angles': {u'layer_0': 41.57891613420559,
#    u'layer_1': 11.140777544257393}},
#  u'epoch_7': {u'delta_angles': {u'layer_1': 20.104821393595333},
#   u'loss': 0.775488804798049,
#   u'test_accuracy': 89.93,
#   u'weight_angles': {u'layer_0': 74.19774268022971,
#    u'layer_1': 31.21582491089467}},
#  u'epoch_70': {u'delta_angles': {u'layer_1': 11.821858473203134},
#   u'loss': 0.15149172313755765,
#   u'test_accuracy': 97.33,
#   u'weight_angles': {u'layer_0': 41.16195028430671,
#    u'layer_1': 11.070558375358628}},
#  u'epoch_71': {u'delta_angles': {u'layer_1': 11.665517357288133},
#   u'loss': 0.14858835733315034,
#   u'test_accuracy': 97.34,
#   u'weight_angles': {u'layer_0': 40.77765882555443,
#    u'layer_1': 10.995618894550603}},
#  u'epoch_72': {u'delta_angles': {u'layer_1': 11.504643541444743},
#   u'loss': 0.1457598270381753,
#   u'test_accuracy': 97.36,
#   u'weight_angles': {u'layer_0': 40.50278078404307,
#    u'layer_1': 10.892731274749943}},
#  u'epoch_73': {u'delta_angles': {u'layer_1': 11.362125095219676},
#   u'loss': 0.14300330483048643,
#   u'test_accuracy': 97.4,
#   u'weight_angles': {u'layer_0': 40.21097738917819,
#    u'layer_1': 10.788741909900892}},
#  u'epoch_74': {u'delta_angles': {u'layer_1': 11.236137934251083},
#   u'loss': 0.14031644380536976,
#   u'test_accuracy': 97.41,
#   u'weight_angles': {u'layer_0': 40.00047786496021,
#    u'layer_1': 10.749665609537038}},
#  u'epoch_75': {u'delta_angles': {u'layer_1': 11.101585394474203},
#   u'loss': 0.13769669586104394,
#   u'test_accuracy': 97.44,
#   u'weight_angles': {u'layer_0': 39.556397312551276,
#    u'layer_1': 10.66002438365311}},
#  u'epoch_76': {u'delta_angles': {u'layer_1': 10.922022598302748},
#   u'loss': 0.1351401865683684,
#   u'test_accuracy': 97.46,
#   u'weight_angles': {u'layer_0': 39.19694885356226,
#    u'layer_1': 10.599363848202163}},
#  u'epoch_77': {u'delta_angles': {u'layer_1': 10.790228581046772},
#   u'loss': 0.13264610672115182,
#   u'test_accuracy': 97.49,
#   u'weight_angles': {u'layer_0': 39.00681101446733,
#    u'layer_1': 10.510790491796211}},
#  u'epoch_78': {u'delta_angles': {u'layer_1': 10.729783656003065},
#   u'loss': 0.13021172038152073,
#   u'test_accuracy': 97.54,
#   u'weight_angles': {u'layer_0': 38.8077485913641,
#    u'layer_1': 10.463163744648284}},
#  u'epoch_79': {u'delta_angles': {u'layer_1': 10.658133560303844},
#   u'loss': 0.1278352013218375,
#   u'test_accuracy': 97.55,
#   u'weight_angles': {u'layer_0': 38.54964756764393,
#    u'layer_1': 10.460931127423242}},
#  u'epoch_8': {u'delta_angles': {u'layer_1': 18.652885407104545},
#   u'loss': 0.7482391509972147,
#   u'test_accuracy': 90.18,
#   u'weight_angles': {u'layer_0': 73.25931807518184,
#    u'layer_1': 29.313030748924273}},
#  u'epoch_80': {u'delta_angles': {u'layer_1': 10.597000742045497},
#   u'loss': 0.1255141494615388,
#   u'test_accuracy': 97.56,
#   u'weight_angles': {u'layer_0': 38.08541990532188,
#    u'layer_1': 10.380949924735562}},
#  u'epoch_81': {u'delta_angles': {u'layer_1': 10.52009233497793},
#   u'loss': 0.1232461056787118,
#   u'test_accuracy': 97.57,
#   u'weight_angles': {u'layer_0': 37.73863959051097,
#    u'layer_1': 10.313204996073372}},
#  u'epoch_82': {u'delta_angles': {u'layer_1': 10.43297304894605},
#   u'loss': 0.12102928402600635,
#   u'test_accuracy': 97.59,
#   u'weight_angles': {u'layer_0': 37.47758431808937,
#    u'layer_1': 10.259358465506175}},
#  u'epoch_83': {u'delta_angles': {u'layer_1': 10.417111216849058},
#   u'loss': 0.11886334050511123,
#   u'test_accuracy': 97.61,
#   u'weight_angles': {u'layer_0': 37.12086808958068,
#    u'layer_1': 10.191648385466065}},
#  u'epoch_84': {u'delta_angles': {u'layer_1': 10.214427003210906},
#   u'loss': 0.11674490470269794,
#   u'test_accuracy': 97.61,
#   u'weight_angles': {u'layer_0': 36.81424566741619,
#    u'layer_1': 10.095037746378717}},
#  u'epoch_85': {u'delta_angles': {u'layer_1': 10.167027203975701},
#   u'loss': 0.11467282153065579,
#   u'test_accuracy': 97.63,
#   u'weight_angles': {u'layer_0': 36.59953132654593,
#    u'layer_1': 10.043184365355566}},
#  u'epoch_86': {u'delta_angles': {u'layer_1': 10.160280303894831},
#   u'loss': 0.11264617295785957,
#   u'test_accuracy': 97.66,
#   u'weight_angles': {u'layer_0': 36.317553991334805,
#    u'layer_1': 10.017009281813252}},
#  u'epoch_87': {u'delta_angles': {u'layer_1': 10.087061152394295},
#   u'loss': 0.11066349876197903,
#   u'test_accuracy': 97.67,
#   u'weight_angles': {u'layer_0': 36.10304369719653,
#    u'layer_1': 9.933249446252281}},
#  u'epoch_88': {u'delta_angles': {u'layer_1': 9.95313194033318},
#   u'loss': 0.1087227050969469,
#   u'test_accuracy': 97.7,
#   u'weight_angles': {u'layer_0': 35.93850509951702,
#    u'layer_1': 9.881255327017133}},
#  u'epoch_89': {u'delta_angles': {u'layer_1': 9.7576024736091},
#   u'loss': 0.10682229930093062,
#   u'test_accuracy': 97.71,
#   u'weight_angles': {u'layer_0': 35.810451236724504,
#    u'layer_1': 9.81706615105869}},
#  u'epoch_9': {u'delta_angles': {u'layer_1': 16.906748050473386},
#   u'loss': 0.7253982117565481,
#   u'test_accuracy': 90.49,
#   u'weight_angles': {u'layer_0': 72.22495248052763,
#    u'layer_1': 27.453598418258952}},
#  u'epoch_90': {u'delta_angles': {u'layer_1': 9.72428992174188},
#   u'loss': 0.10496273306928416,
#   u'test_accuracy': 97.74,
#   u'weight_angles': {u'layer_0': 35.63221932373986,
#    u'layer_1': 9.762271431241768}},
#  u'epoch_91': {u'delta_angles': {u'layer_1': 9.631498193650982},
#   u'loss': 0.10314086007546047,
#   u'test_accuracy': 97.75,
#   u'weight_angles': {u'layer_0': 35.362441677089535,
#    u'layer_1': 9.698251141355703}},
#  u'epoch_92': {u'delta_angles': {u'layer_1': 9.611267296349041},
#   u'loss': 0.1013563081598428,
#   u'test_accuracy': 97.78,
#   u'weight_angles': {u'layer_0': 35.118523568920544,
#    u'layer_1': 9.67726247944184}},
#  u'epoch_93': {u'delta_angles': {u'layer_1': 9.50051190282639},
#   u'loss': 0.09960786855944509,
#   u'test_accuracy': 97.8,
#   u'weight_angles': {u'layer_0': 34.96116900773959,
#    u'layer_1': 9.587788035009247}},
#  u'epoch_94': {u'delta_angles': {u'layer_1': 9.465840152862189},
#   u'loss': 0.0978940656535925,
#   u'test_accuracy': 97.8,
#   u'weight_angles': {u'layer_0': 34.83892792216895,
#    u'layer_1': 9.526584302838842}},
#  u'epoch_95': {u'delta_angles': {u'layer_1': 9.442377700090235},
#   u'loss': 0.09621397178008317,
#   u'test_accuracy': 97.85,
#   u'weight_angles': {u'layer_0': 34.64728248426991,
#    u'layer_1': 9.484825638356938}},
#  u'epoch_96': {u'delta_angles': {u'layer_1': 9.332393054620336},
#   u'loss': 0.09456751923148697,
#   u'test_accuracy': 97.9,
#   u'weight_angles': {u'layer_0': 34.563294370303986,
#    u'layer_1': 9.43017615504918}},
#  u'epoch_97': {u'delta_angles': {u'layer_1': 9.253284749323598},
#   u'loss': 0.09295347948107005,
#   u'test_accuracy': 97.92,
#   u'weight_angles': {u'layer_0': 34.3471365488096,
#    u'layer_1': 9.377864072062284}},
#  u'epoch_98': {u'delta_angles': {u'layer_1': 9.2226367531654},
#   u'loss': 0.09137087743438976,
#   u'test_accuracy': 97.96,
#   u'weight_angles': {u'layer_0': 34.16080415761885,
#    u'layer_1': 9.369149216629266}},
#  u'epoch_99': {u'delta_angles': {u'layer_1': 9.137156959439888},
#   u'loss': 0.0898188637891999,
#   u'test_accuracy': 97.97,
#   u'weight_angles': {u'layer_0': 33.85801191285213,
#    u'layer_1': 9.320289811256819}}}
